# %% [markdown]
# ### Traffic encoding level 0: roundabout

# %% [markdown]
# #### How to write a function in python:

# %%
# This is how you write fucntion in python:
def my_fucntion_name():        # use the keyword def
    print ("hello world")      # write code, make things happen

#When you want to use that function, just call it.
my_fucntion_name()             # call the function
# Out:
# hello world

# %% [markdown]
# Now you try to write a function named `hello_world` that will print the text `"Hello world!"`

# %%
## TODO: enter the code here for the task listed above.

# %%
# this is how to add a variable to function:
def function_name(variable):  # variable can be named as anything, it's just a place holder
  print(variable)

# now when you call the function, you have to input the variable too.
function_name ("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Now you try to write a function named `hello_you` that will say hello to `your lab partner's name`.

# %%
## TODO: enter the code here for the task listed above.

# %%
print ("something")                  # this is just for us human to see

def power_of_2 (x):                  # define a function named "power of 2", with x as variable
  return 2**x                        # this will send data back to python

power_of_2 (3)                       # what will be the output?
# Out:
# something
# 8

# %%
the_answer = power_of_2 (4)          # we can assign the output to a variable named the_answer
print (the_answer)                   # and python will remember the output
# Out:
# 16

# %% [markdown]
# #### Now let's do a roundabout function to turn that car around!

# %%
number_array = [2,3,4,5]        # this is a number array
len(number_array)               # this will return the length
# Out:
# 4

# %%
number_array = [5,4,3,2]        # this is a number array
number_array[-1]                # this will return what?
# Out:
# 2

# %%
for i in range(2,11,2):           # i will iterate through range
  print (i)                       # waht will be the answer?
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
# A car (in lane_a) is coming into a dead-end, after 3 ticks of time, it will enter the roundabout.
lane_a = [0,0,1,0] # A number array is used to encoding one car in one lane. Each index is a time point.
                   # After it exit, it will become [0,0,-1,0]

## TODO: finish up the follwoing function for this application:

def roundabout(lane_to_be_checked):             # This dead_end function needs one variable (a number array called "lane to be checked").
  for i in range(len(lane_to_be_checked)):                     # Use len to get length of the array (how many ticks in total); use range to iterate through each tick.
    if ## TODO: find the car
       ## TODO: flip the car from 1 to -1
    return lane_to_be_checked                                   # This is the output of this function.

# %%
## test this function by run this following code

lane_b = [0,1,0,1,0]
roundabout (lane_b)
# Out:
# [0, 1, 0, 1, 0]

# %% [markdown]
# ### Traffice encoding level 1: intersection

# %%
# define traffic in two lanes
Fifteenth_ST = [0,0,1,0,0]
Sixth_AVE = [0,0,1,0,0]

# %%
# Collision check:

# TODO: fix the code and make collision detection work
def collision_check (lane_x, lane_y):  # This collision_check function needs two inputs (two number arrays).
  collision_mark = [0]*(len(lane_x))   # This is an empty nubmer array (all 0), so we can return collision info for reports.
  for i in range(len(lane_x)):
    if lane_x[i] == lane_y[i]:
      print(f"Collision detected at: {i}'s tick at 15th_St and 6th_Ave!")  # This is the fancy print function, please get used to it since we gonna need it to return messages.
      collision_mark[i] = True
  return collision_mark
collision_check (Fifteenth_ST, Sixth_AVE)
# Out:
# Collision detected at: 0's tick at 15th_St and 6th_Ave!
# Collision detected at: 1's tick at 15th_St and 6th_Ave!
# Collision detected at: 2's tick at 15th_St and 6th_Ave!
# Collision detected at: 3's tick at 15th_St and 6th_Ave!
# Collision detected at: 4's tick at 15th_St and 6th_Ave!
# [True, True, True, True, True]

# %%
# This is how you can shift 1 to the left for number array:
test_lane = [0,0,1,0,0]
test_lane.insert (2,0) # insert (i,j): i is the index, and 0 is the insert value
test_lane.pop() # this is to remove the last bit so the length of the array is stil the same
print(test_lane)
# Out:
# [0, 0, 0, 1, 0]

# %%
## TODO: do something so the 1 in the street is shifted one bit behind
def street_delay (any_lane):
  for i in range(len(any_lane)):
    if collision_mark[i] == True:
      ## TODO

# %%
##TODO: test if the traffic control could work here.

def traffic_control (lane_i, lane_j):
  collision_check (lane_i, lane_j)
  street_delay () ##TODO which raviable to fill in here?
  return () ##TODO which raviable to fill in here?

traffic_control (Fifteenth_ST, Sixth_AVE)
# Out:
# Collision detected at: 0's tick at 15th_St and 6th_Ave!
# Collision detected at: 1's tick at 15th_St and 6th_Ave!
# Collision detected at: 2's tick at 15th_St and 6th_Ave!
# Collision detected at: 3's tick at 15th_St and 6th_Ave!
# Collision detected at: 4's tick at 15th_St and 6th_Ave!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3343594966.py in <cell line: 0>()
#       6   return () ##TODO which raviable to fill in here?
#       7
# ----> 8 traffic_control (Fifteenth_ST, Sixth_AVE)
#
# /tmp/ipython-input-3343594966.py in traffic_control(lane_i, lane_j)
#       3 def traffic_control (lane_i, lane_j):
#       4   collision_check (lane_i, lane_j)
# ----> 5   street_delay () ##TODO which raviable to fill in here?
#       6   return () ##TODO which raviable to fill in here?
#       7
#
# ...

# %%
# test your traffic_control algo here:
Fifteenth_ST = [0,1,1,0,0]
Sixth_AVE = [0,0,1,0,1]
traffic_control (Fifteenth_ST, Sixth_AVE)
# Out:
# Collision detected at: 0's tick at 15th_St and 6th_Ave!
# Collision detected at: 2's tick at 15th_St and 6th_Ave!
# Collision detected at: 3's tick at 15th_St and 6th_Ave!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1908396172.py in <cell line: 0>()
#       2 Fifteenth_ST = [0,1,1,0,0]
#       3 Sixth_AVE = [0,0,1,0,1]
# ----> 4 traffic_control (Fifteenth_ST, Sixth_AVE)
#
# /tmp/ipython-input-3343594966.py in traffic_control(lane_i, lane_j)
#       3 def traffic_control (lane_i, lane_j):
#       4   collision_check (lane_i, lane_j)
# ----> 5   street_delay () ##TODO which raviable to fill in here?
#       6   return () ##TODO which raviable to fill in here?
#       7
#
# TypeError: street_delay() missing 1 required positional argument: 'any_lane'

# %% [markdown]
# ### Traffic encoding level 2: highway merge lane

# %%
#I have two choice on 8th ST.
Right = 1
Left = 2

Eighth_ST = [0,Left,Right,0,0]
Interstate_380 = [1,1,1,0,1,1,0,1,1]

print (Eighth_ST) ## TODO: check what will happen?
# Out:
# [0, 2, 1, 0, 0]

# %%
#Now we need to get both the index number, and the value.
def choice_on_8th (lane_a, lane_b):
for i, states in enumerate(lane_a):
 if states == 0:
  ## TODO: do something to continue the next tick?
 elif states == Left:
  ## TODO: do something to turn left?
 elif states == Right:
  ## TODO: do something to turn right?
  ## TODO: if merge, need collision detection and delay_lane if necessary
  ## TODO: when merge, need to add this car to I380, and remove it from 8th st.
# Out:
#   File "/tmp/ipython-input-3712065977.py", line 3
#     for i, states in enumerate(lane_a):
#     ^
# IndentationError: expected an indented block after function definition on line 2

# %%
## TODO: write down any function you need, and test the highway merge fucntion here:
choice_on_8th (Eighth_ST, Interstate_380)
print(f"Traffic on 8th: {Eighth_ST}")
print(f"Traffic on I380: {Interstate_380}")

# %% [markdown]
# ###Bonus:
# Traffic encoding level 1B:
#
# Alternative encoding -bitwise operation or string slicing

# %%
# what if number array is not the best way to sotre info for this task?
lane_a = 0b00100
lane_b = 0b00100

bin(lane_a & lane_b) ## TODO: what will be the answer?
# Out:
# '0b100'

# %% [markdown]
# In vanilla python, 0b00100 is the same as 0b100. Let's say it's a "visual bug".

# %%
bin(0b00100 >> 1) ## TODO: what is the meaning of this?
# Out:
# '0b10'

# %%
# can you write a collision detection and delay lane_b with bitwise operation then?

# %%
# what if we use string to represent lanes? There will be no visual bug for sure.
lane_a = "00100"
lane_b = "00100"

# how to do collision check?

# how to do "bit shift" in string?
lane_b = "0"+ lane_b[:-1] # "0" added to the start, then slice [:-1] cut off the last character
print (lane_b)
# Out:
# 00010
